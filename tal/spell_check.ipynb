# %%
# -*- coding: utf-8 -*-
from __future__ import print_function, division, unicode_literals

import os
import errno
from collections import Counter
from hashlib import sha256
import re
import json
import itertools
import logging
import requests
import numpy as np
from numpy.random import choice as random_choice, randint as random_randint, shuffle as random_shuffle, seed as random_seed, rand
from numpy import zeros as np_zeros # pylint:disable=no-name-in-module

from keras.models import Sequential, load_model
from keras.layers import Activation, TimeDistributed, Dense, RepeatVector, Dropout, recurrent
from keras.callbacks import Callback

# %%
# Set a logger for the module
LOGGER = logging.getLogger(__name__) # Every log will use the module name
LOGGER.addHandler(logging.StreamHandler())
LOGGER.setLevel(logging.DEBUG)

random_seed(123) # Reproducibility

# %%
class Configuration(object):
    """Dump stuff here"""

CONFIG = Configuration()
#pylint:disable=attribute-defined-outside-init
# Parameters for the model:
CONFIG.input_layers = 2
CONFIG.output_layers = 2
CONFIG.amount_of_dropout = 0.2
CONFIG.hidden_size = 500
CONFIG.initialization = "he_normal" # : Gaussian initialization scaled by fan-in (He et al., 2014)
CONFIG.number_of_chars = 100
CONFIG.max_input_len = 60
CONFIG.inverted = True

# parameters for the training:
CONFIG.batch_size = 100 # As the model changes in size, play with the batch size to best fit the process in memory
CONFIG.epochs = 500 # due to mini-epochs.
CONFIG.steps_per_epoch = 1000 # This is a mini-epoch. Using News 2013 an epoch would need to be ~60K.
CONFIG.validation_steps = 10
CONFIG.number_of_iterations = 10
#pylint:enable=attribute-defined-outside-init

DIGEST = sha256(json.dumps(CONFIG.__dict__, sort_keys=True)).hexdigest()

# Parameters for the dataset
MIN_INPUT_LEN = 5
AMOUNT_OF_NOISE = 0.2 / CONFIG.max_input_len
CHARS = list("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ .") #numbers?
PADDING = "☕"

DATA_FILES_PATH = "~/ir646/tal_data"
DATA_FILES_FULL_PATH = os.path.expanduser(DATA_FILES_PATH)
DATA_FILES_URL = "http://www.statmt.org/wmt14/training-monolingual-news-crawl/news.2013.en.shuffled.gz"
NEWS_FILE_NAME_COMPRESSED = os.path.join(DATA_FILES_FULL_PATH, "news.2013.en.shuffled.gz") # 1.1 GB
NEWS_FILE_NAME_ENGLISH = "news.2013.en.shuffled"
NEWS_FILE_NAME = os.path.join(DATA_FILES_FULL_PATH, NEWS_FILE_NAME_ENGLISH)
NEWS_FILE_NAME_CLEAN = os.path.join(DATA_FILES_FULL_PATH, "news.2013.en.clean")
NEWS_FILE_NAME_FILTERED = os.path.join(DATA_FILES_FULL_PATH, "news.2013.en.filtered")
NEWS_FILE_NAME_SPLIT = os.path.join(DATA_FILES_FULL_PATH, "news.2013.en.split")
NEWS_FILE_NAME_TRAIN = os.path.join(DATA_FILES_FULL_PATH, "news.2013.en.train")
NEWS_FILE_NAME_VALIDATE = os.path.join(DATA_FILES_FULL_PATH, "news.2013.en.validate")
CHAR_FREQUENCY_FILE_NAME = os.path.join(DATA_FILES_FULL_PATH, "char_frequency.json")
#SAVED_MODEL_FILE_NAME = os.path.join(DATA_FILES_FULL_PATH, "keras_spell_e{}.h5") # an HDF5 file
SAVED_MODEL_FILE_NAME = os.path.join(DATA_FILES_FULL_PATH, "keras_spell_e") # an HDF5 file

# Some cleanup:
NORMALIZE_WHITESPACE_REGEX = re.compile(r'[^\S\n]+', re.UNICODE) # match all whitespace except newlines
RE_DASH_FILTER = re.compile(r'[\-\˗\֊\‐\‑\‒\–\—\⁻\₋\−\﹣\－]', re.UNICODE)
RE_APOSTROPHE_FILTER = re.compile(r'&#39;|[ʼ՚＇‘’‛❛❜ߴߵ`‵´ˊˋ{}{}{}{}{}{}{}{}{}]'.format(unichr(768), unichr(769), unichr(832),unichr(833), unichr(2387), unichr(5151),unichr(5152), unichr(65344), unichr(8242)),re.UNICODE)
RE_LEFT_PARENTH_FILTER = re.compile(r'[\(\[\{\⁽\₍\❨\❪\﹙\（]', re.UNICODE)
RE_RIGHT_PARENTH_FILTER = re.compile(r'[\)\]\}\⁾\₎\❩\❫\﹚\）]', re.UNICODE)
ALLOWED_CURRENCIES = """¥£₪$€฿₨"""
ALLOWED_PUNCTUATION = """-!?/;"'%&<>.()[]{}@#:,|=*"""
RE_BASIC_CLEANER = re.compile(r'[^\w\s{}{}]'.format(re.escape(ALLOWED_CURRENCIES), re.escape(ALLOWED_PUNCTUATION)), re.UNICODE)

# pylint:disable=invalid-name

# %%
def download_the_news_data():
    """Download the news data"""
    LOGGER.info("Downloading")
    try:
        os.makedirs(os.path.dirname(NEWS_FILE_NAME_COMPRESSED))
    except OSError as exception:
        if exception.errno != errno.EEXIST:
            raise
    with open(NEWS_FILE_NAME_COMPRESSED, "wb") as output_file:
        response = requests.get(DATA_FILES_URL, stream=True)
        total_length = response.headers.get('content-length')
        downloaded = percentage = 0
        print("»"*100)
        total_length = int(total_length)
        for data in response.iter_content(chunk_size=4096):
            downloaded += len(data)
            output_file.write(data)
            new_percentage = 100 * downloaded // total_length
            if new_percentage > percentage:
                print("☑", end="")
                percentage = new_percentage
    print()

def uncompress_data():
    """Uncompress the data files"""
    import gzip
    with gzip.open(NEWS_FILE_NAME_COMPRESSED, 'rb') as compressed_file:
        with open(NEWS_FILE_NAME_COMPRESSED[:-3], 'wb') as outfile:
            outfile.write(compressed_file.read())

def add_noise_to_string(a_string, amount_of_noise):
    """Add some artificial spelling mistakes to the string"""
    if rand() < amount_of_noise * len(a_string):
        # Replace a character with a random character
        random_char_position = random_randint(len(a_string))
        a_string = a_string[:random_char_position] + random_choice(CHARS[:-1]) + a_string[random_char_position + 1:]
    if rand() < amount_of_noise * len(a_string):
        # Delete a character
        random_char_position = random_randint(len(a_string))
        a_string = a_string[:random_char_position] + a_string[random_char_position + 1:]
    if len(a_string) < CONFIG.max_input_len and rand() < amount_of_noise * len(a_string):
        # Add a random character
        random_char_position = random_randint(len(a_string))
        a_string = a_string[:random_char_position] + random_choice(CHARS[:-1]) + a_string[random_char_position:]
    if rand() < amount_of_noise * len(a_string):
        # Transpose 2 characters
        random_char_position = random_randint(len(a_string) - 1)
        a_string = (a_string[:random_char_position] + a_string[random_char_position + 1] + a_string[random_char_position] +
                    a_string[random_char_position + 2:])
    return a_string

# %%
def _vectorize(questions, answers, ctable):
    """Vectorize the data as numpy arrays"""
    len_of_questions = len(questions)
    X = np_zeros((len_of_questions, CONFIG.max_input_len, ctable.size), dtype=np.bool)
    for i in xrange(len(questions)):
        sentence = questions.pop()
        for j, c in enumerate(sentence):
            try:
                X[i, j, ctable.char_indices[c]] = 1
            except KeyError:
                pass # Padding
    y = np_zeros((len_of_questions, CONFIG.max_input_len, ctable.size), dtype=np.bool)
    for i in xrange(len(answers)):
        sentence = answers.pop()
        for j, c in enumerate(sentence):
            try:
                y[i, j, ctable.char_indices[c]] = 1
            except KeyError:
                pass # Padding
    return X, y

def slice_X(X, start=None, stop=None):
    """This takes an array-like, or a list of
    array-likes, and outputs:
        - X[start:stop] if X is an array-like
        - [x[start:stop] for x in X] if X in a list
    Can also work on list/array of indices: `slice_X(x, indices)`
    # Arguments
        start: can be an integer index (start index)
            or a list/array of indices
        stop: integer (stop index); should be None if
            `start` was a list.
    """
    if isinstance(X, list):
        if hasattr(start, '__len__'):
            # hdf5 datasets only support list objects as indices
            if hasattr(start, 'shape'):
                start = start.tolist()
            return [x[start] for x in X]
        else:
            return [x[start:stop] for x in X]
    else:
        if hasattr(start, '__len__'):
            if hasattr(start, 'shape'):
                start = start.tolist()
            return X[start]
        else:
            return X[start:stop]

def vectorize(questions, answers, chars=None):
    """Vectorize the questions and expected answers"""
    print('Vectorization...')
    chars = chars or CHARS
    ctable = CharacterTable(chars)
    X, y = _vectorize(questions, answers, ctable)
    # Explicitly set apart 10% for validation data that we never train over
    split_at = int(len(X) - len(X) / 10)
    (X_train, X_val) = (slice_X(X, 0, split_at), slice_X(X, split_at))
    (y_train, y_val) = (y[:split_at], y[split_at:])

    print(X_train.shape)
    print(y_train.shape)

    return X_train, X_val, y_train, y_val, CONFIG.max_input_len, ctable

# %%
def generate_model(output_len, chars=None):
    """Generate the model"""
    print('Build model...')
    chars = chars or CHARS
    model = Sequential()
    # "Encode" the input sequence using an RNN, producing an output of hidden_size
    # note: in a situation where your input sequences have a variable length,
    # use input_shape=(None, nb_feature).
    for layer_number in range(CONFIG.input_layers):
        model.add(recurrent.LSTM(CONFIG.hidden_size, input_shape=(None, len(chars)), kernel_initializer=CONFIG.initialization,
                                 return_sequences=layer_number + 1 < CONFIG.input_layers))
        model.add(Dropout(CONFIG.amount_of_dropout))
    # For the decoder's input, we repeat the encoded input for each time step
    model.add(RepeatVector(output_len))
    # The decoder RNN could be multiple layers stacked or a single layer
    for _ in range(CONFIG.output_layers):
        model.add(recurrent.LSTM(CONFIG.hidden_size, return_sequences=True, kernel_initializer=CONFIG.initialization))
        model.add(Dropout(CONFIG.amount_of_dropout))

    # For each of step of the output sequence, decide which character should be chosen
    model.add(TimeDistributed(Dense(len(chars), kernel_initializer=CONFIG.initialization)))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model


class Colors(object):
    """For nicer printouts"""
    green = '\033[92m'
    red = '\033[91m'
    close = '\033[0m'

# %%
class CharacterTable(object):
    """
    Given a set of characters:
    + Encode them to a one hot integer representation
    + Decode the one hot integer representation to their character output
    + Decode a vector of probabilities to their character output
    """
    def __init__(self, chars):
        self.chars = sorted(set(chars))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))

    @property
    def size(self):
        """The number of chars"""
        return len(self.chars)

    def encode(self, C, maxlen):
        """Encode as one-hot"""
        X = np_zeros((maxlen, len(self.chars)), dtype=np.bool) # pylint:disable=no-member
        for i, c in enumerate(C):
            X[i, self.char_indices[c]] = 1
        return X

    def decode(self, X, calc_argmax=True):
        """Decode from one-hot"""
        if calc_argmax:
            X = X.argmax(axis=-1)
        return ''.join(self.indices_char[x] for x in X if x)

def generator(file_name):
    """Returns a tuple (inputs, targets)
    All arrays should contain the same number of samples.
    The generator is expected to loop over its data indefinitely.
    An epoch finishes when  samples_per_epoch samples have been seen by the model.
    """
    ctable = CharacterTable(read_top_chars())
    batch_of_answers = []
    while True:
        with open(file_name) as answers:
            for answer in answers:
                batch_of_answers.append(answer.strip().decode('utf-8'))
                if len(batch_of_answers) == CONFIG.batch_size:
                    random_shuffle(batch_of_answers)
                    batch_of_questions = []
                    for answer_index, answer in enumerate(batch_of_answers):
                        question, answer = generate_question(answer)
                        batch_of_answers[answer_index] = answer
                        assert len(answer) == CONFIG.max_input_len
                        question = question[::-1] if CONFIG.inverted else question
                        batch_of_questions.append(question)
                    X, y = _vectorize(batch_of_questions, batch_of_answers, ctable)
                    yield X, y
                    batch_of_answers = []

# %%
def print_random_predictions(model, ctable, X_val, y_val):
    """Select 10 samples from the validation set at random so we can visualize errors"""
    print()
    for _ in range(10):
        ind = random_randint(0, len(X_val))
        rowX, rowy = X_val[np.array([ind])], y_val[np.array([ind])] # pylint:disable=no-member
        preds = model.predict_classes(rowX, verbose=0)
        q = ctable.decode(rowX[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        if CONFIG.inverted:
            print('Q', q[::-1]) # inverted back!
        else:
            print('Q', q)
        print('A', correct)
        print(Colors.green + '☑' + Colors.close if correct == guess else Colors.red + '☒' + Colors.close, guess)
        print('---')
    print()


class OnEpochEndCallback(Callback):
    """Execute this every end of epoch"""

    def on_epoch_end(self, epoch, logs=None):
        """On Epoch end - do some stats"""
        ctable = CharacterTable(read_top_chars())
        X_val, y_val = next(generator(NEWS_FILE_NAME_VALIDATE))
        print_random_predictions(self.model, ctable, X_val, y_val)
        #self.model.save(SAVED_MODEL_FILE_NAME.format(epoch))
        self.model.save(str(SAVED_MODEL_FILE_NAME+str(epoch)+".h5"))

ON_EPOCH_END_CALLBACK = OnEpochEndCallback()

# %%
def itarative_train(model):
    """
    Iterative training of the model
     - To allow for finite RAM...
     - To allow infinite training data as the training noise is injected in runtime
    """
    model.fit_generator(generator(NEWS_FILE_NAME_TRAIN), steps_per_epoch=CONFIG.steps_per_epoch,
                        epochs=CONFIG.epochs,
                        verbose=1, callbacks=[ON_EPOCH_END_CALLBACK, ], validation_data=generator(NEWS_FILE_NAME_VALIDATE),
                        validation_steps=CONFIG.validation_steps,
                        class_weight=None, max_q_size=10, workers=1,
                        pickle_safe=False, initial_epoch=0)


def iterate_training(model, X_train, y_train, X_val, y_val, ctable):
    """Iterative Training"""
    # Train the model each generation and show predictions against the validation dataset
    for iteration in range(1, CONFIG.number_of_iterations):
        print()
        print('-' * 50)
        print('Iteration', iteration)
        model.fit(X_train, y_train, batch_size=CONFIG.batch_size, epochs=CONFIG.epochs,
                  validation_data=(X_val, y_val))
        print_random_predictions(model, ctable, X_val, y_val)

def clean_text(text):
    """Clean the text - remove unwanted chars, fold punctuation etc."""
    result = NORMALIZE_WHITESPACE_REGEX.sub(' ', text.strip())
    result = RE_DASH_FILTER.sub('-', result)
    result = RE_APOSTROPHE_FILTER.sub("'", result)
    result = RE_LEFT_PARENTH_FILTER.sub("(", result)
    result = RE_RIGHT_PARENTH_FILTER.sub(")", result)
    result = RE_BASIC_CLEANER.sub('', result)
    return result

def preprocesses_data_clean():
    """Pre-process the data - step 1 - cleanup"""
    with open(NEWS_FILE_NAME_CLEAN, "wb") as clean_data:
        for line in open(NEWS_FILE_NAME):
            decoded_line = line.decode('utf-8')
            cleaned_line = clean_text(decoded_line)
            encoded_line = cleaned_line.encode("utf-8")
            clean_data.write(encoded_line + b"\n")

def preprocesses_data_analyze_chars():
    """Pre-process the data - step 2 - analyze the characters"""
    counter = Counter()
    LOGGER.info("Reading data:")
    for line in open(NEWS_FILE_NAME_CLEAN):
        decoded_line = line.decode('utf-8')
        counter.update(decoded_line)
    #     data = open(NEWS_FILE_NAME_CLEAN).read().decode('utf-8')
    #     LOGGER.info("Read.\nCounting characters:")
    #     counter = Counter(data.replace("\n", ""))
    LOGGER.info("Done.\nWriting to file:")
    with open(CHAR_FREQUENCY_FILE_NAME, 'wb') as output_file:
        output_file.write(json.dumps(counter))
    most_popular_chars = {key for key, _value in counter.most_common(CONFIG.number_of_chars)}
    LOGGER.info("The top %s chars are:", CONFIG.number_of_chars)
    LOGGER.info("".join(sorted(most_popular_chars)))

def read_top_chars():
    """Read the top chars we saved to file"""
    chars = json.loads(open(CHAR_FREQUENCY_FILE_NAME).read())
    counter = Counter(chars)
    most_popular_chars = {key for key, _value in counter.most_common(CONFIG.number_of_chars)}
    return most_popular_chars

def preprocesses_data_filter():
    """Pre-process the data - step 3 - filter only sentences with the right chars"""
    most_popular_chars = read_top_chars()
    LOGGER.info("Reading and filtering data:")
    with open(NEWS_FILE_NAME_FILTERED, "wb") as output_file:
        for line in open(NEWS_FILE_NAME_CLEAN):
            decoded_line = line.decode('utf-8')
            if decoded_line and not bool(set(decoded_line) - most_popular_chars):
                output_file.write(line)
    LOGGER.info("Done.")

def read_filtered_data():
    """Read the filtered data corpus"""
    LOGGER.info("Reading filtered data:")
    lines = open(NEWS_FILE_NAME_FILTERED).read().decode('utf-8').split("\n")
    LOGGER.info("Read filtered data - %s lines", len(lines))
    return lines

def preprocesses_split_lines():
    """Preprocess the text by splitting the lines between min-length and max_length
    I don't like this step:
      I think the start-of-sentence is important.
      I think the end-of-sentence is important.
      Sometimes the stripped down sub-sentence is missing crucial context.
      Important NGRAMs are cut (though given enough data, that might be moot).
    I do this to enable batch-learning by padding to a fixed length.
    """
    LOGGER.info("Reading filtered data:")
    answers = set()
    with open(NEWS_FILE_NAME_SPLIT, "wb") as output_file:
        for _line in open(NEWS_FILE_NAME_FILTERED):
            line = _line.decode('utf-8')
            while len(line) > MIN_INPUT_LEN:
                if len(line) <= CONFIG.max_input_len:
                    answer = line
                    line = ""
                else:
                    space_location = line.rfind(" ", MIN_INPUT_LEN, CONFIG.max_input_len - 1)
                    if space_location > -1:
                        answer = line[:space_location]
                        line = line[len(answer) + 1:]
                    else:
                        space_location = line.rfind(" ") # no limits this time
                        if space_location == -1:
                            break # we are done with this line
                        else:
                            line = line[space_location + 1:]
                            continue
                answers.add(answer)
                output_file.write(answer.encode('utf-8') + b"\n")

def preprocesses_split_lines2():
    """Preprocess the text by splitting the lines between min-length and max_length
    Alternative split.
    """
    LOGGER.info("Reading filtered data:")
    answers = set()
    for encoded_line in open(NEWS_FILE_NAME_FILTERED):
        line = encoded_line.decode('utf-8')
        if CONFIG.max_input_len >= len(line) > MIN_INPUT_LEN:
            answers.add(line)
    LOGGER.info("There are %s 'answers' (sub-sentences)", len(answers))
    LOGGER.info("Here are some examples:")
    for answer in itertools.islice(answers, 10):
        LOGGER.info(answer)
    with open(NEWS_FILE_NAME_SPLIT, "wb") as output_file:
        output_file.write("".join(answers).encode('utf-8'))

def preprocesses_split_lines3():
    """Preprocess the text by selecting only max n-grams
    Alternative split.
    """
    LOGGER.info("Reading filtered data:")
    answers = set()
    for encoded_line in open(NEWS_FILE_NAME_FILTERED):
        line = encoded_line.decode('utf-8')
        if line.count(" ") < 5:
            answers.add(line)
    LOGGER.info("There are %s 'answers' (sub-sentences)", len(answers))
    LOGGER.info("Here are some examples:")
    for answer in itertools.islice(answers, 10):
        LOGGER.info(answer)
    with open(NEWS_FILE_NAME_SPLIT, "wb") as output_file:
        output_file.write("".join(answers).encode('utf-8'))

def preprocesses_split_lines4():
    """Preprocess the text by selecting only sentences with most-common words AND not too long
    Alternative split.
    """
    LOGGER.info("Reading filtered data:")
    from gensim.models.word2vec import Word2Vec
    FILTERED_W2V = "fw2v.bin"
    model = Word2Vec.load_word2vec_format(FILTERED_W2V, binary=True) # C text format
    print(len(model.wv.index2word))
#     answers = set()
#     for encoded_line in open(NEWS_FILE_NAME_FILTERED):
#         line = encoded_line.decode('utf-8')
#         if line.count(" ") < 5:
#             answers.add(line)
#     LOGGER.info("There are %s 'answers' (sub-sentences)", len(answers))
#     LOGGER.info("Here are some examples:")
#     for answer in itertools.islice(answers, 10):
#         LOGGER.info(answer)
#     with open(NEWS_FILE_NAME_SPLIT, "wb") as output_file:
#         output_file.write("".join(answers).encode('utf-8'))

def preprocess_partition_data():
    """Set asside data for validation"""
    answers = open(NEWS_FILE_NAME_SPLIT).read().decode('utf-8').split("\n")
    print('shuffle', end=" ")
    random_shuffle(answers)
    print("Done")
    # Explicitly set apart 10% for validation data that we never train over
    split_at = len(answers) - len(answers) // 10
    with open(NEWS_FILE_NAME_TRAIN, "wb") as output_file:
        output_file.write("\n".join(answers[:split_at]).encode('utf-8'))
    with open(NEWS_FILE_NAME_VALIDATE, "wb") as output_file:
        output_file.write("\n".join(answers[split_at:]).encode('utf-8'))


def generate_question(answer):
    """Generate a question by adding noise"""
    question = add_noise_to_string(answer, AMOUNT_OF_NOISE)
    # Add padding:
    question += PADDING * (CONFIG.max_input_len - len(question))
    answer += PADDING * (CONFIG.max_input_len - len(answer))
    return question, answer

def generate_news_data():
    """Generate some news data"""
    print ("Generating Data")
    answers = open(NEWS_FILE_NAME_SPLIT).read().decode('utf-8').split("\n")
    questions = []
    print('shuffle', end=" ")
    random_shuffle(answers)
    print("Done")
    for answer_index, answer in enumerate(answers):
        question, answer = generate_question(answer)
        answers[answer_index] = answer
        assert len(answer) == CONFIG.max_input_len
        if random_randint(100000) == 8: # Show some progress
            print (len(answers))
            print ("answer:   '{}'".format(answer))
            print ("question: '{}'".format(question))
            print ()
        question = question[::-1] if CONFIG.inverted else question
        questions.append(question)

    return questions, answers

def train_speller_w_all_data():
    """Train the speller if all data fits into RAM"""
    questions, answers = generate_news_data()
    chars_answer = set.union(*(set(answer) for answer in answers))
    chars_question = set.union(*(set(question) for question in questions))
    chars = list(set.union(chars_answer, chars_question))
    X_train, X_val, y_train, y_val, y_maxlen, ctable = vectorize(questions, answers, chars)
    print ("y_maxlen, chars", y_maxlen, "".join(chars))
    model = generate_model(y_maxlen, chars)
    iterate_training(model, X_train, y_train, X_val, y_val, ctable)

def train_speller(from_file=None):
    """Train the speller"""
    if from_file:
        model = load_model(str(from_file))
    else:
        model = generate_model(CONFIG.max_input_len, chars=read_top_chars())
    itarative_train(model)
"""
if __name__ == '__main__':
#     download_the_news_data() # generates news.2013.en.shuffled.gz in tal_data/
#     uncompress_data()
#     preprocesses_data_clean()
#     preprocesses_data_analyze_chars()
#     preprocesses_data_filter()
#     preprocesses_split_lines() --- Choose this step or:
#     preprocesses_split_lines2()
#     preprocesses_split_lines4()
#     preprocess_partition_data()
#     train_speller(os.path.join(DATA_FILES_FULL_PATH, "keras_spell_e15.h5"))
    train_speller()
"""
# Out:
# u'\nif __name__ == \'__main__\':\n#     download_the_news_data() # generates news.2013.en.shuffled.gz in tal_data/\n#     uncompress_data()\n#     preprocesses_data_clean()\n#     preprocesses_data_analyze_chars()\n#     preprocesses_data_filter()\n#     preprocesses_split_lines() --- Choose this step or:\n#     preprocesses_split_lines2()\n#     preprocesses_split_lines4()\n#     preprocess_partition_data()\n#     train_speller(os.path.join(DATA_FILES_FULL_PATH, "keras_spell_e15.h5"))\n    train_speller()\n'

# %%
train_speller(os.path.join(DATA_FILES_FULL_PATH, "keras_spell_e217.h5"))
# Out:
# /home/ssatti/miniconda2/envs/talpy2/lib/python2.7/site-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=0, verbose=1, workers=1, validation_data=<generator..., steps_per_epoch=1000, epochs=500, callbacks=[<__main__..., max_queue_size=10, validation_steps=10, use_multiprocessing=False, class_weight=None)`
#   if sys.path[0] == '':
# Epoch 1/500
#   29/1000 [..............................] - ETA: 1:10:36 - loss: 0.2622 - acc: 0.4738
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-14-38cdd436faf9> in <module>()
# ----> 1 train_speller(os.path.join(DATA_FILES_FULL_PATH, "keras_spell_e217.h5"))
#
# <ipython-input-13-7ffefbaaac8a> in train_speller(from_file)
#     234     else:
#     235         model = generate_model(CONFIG.max_input_len, chars=read_top_chars())
# --> 236     itarative_train(model)
#     237 """
#     238 if __name__ == '__main__':
#
# <ipython-input-13-7ffefbaaac8a> in itarative_train(model)
#      10                         validation_steps=CONFIG.validation_steps,
#      11                         class_weight=None, max_q_size=10, workers=1,
# ---> 12                         pickle_safe=False, initial_epoch=0)
#      13
#      14
#
# /home/ssatti/miniconda2/envs/talpy2/lib/python2.7/site-packages/keras/legacy/interfaces.pyc in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /home/ssatti/miniconda2/envs/talpy2/lib/python2.7/site-packages/keras/engine/training.pyc in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /home/ssatti/miniconda2/envs/talpy2/lib/python2.7/site-packages/keras/engine/training_generator.pyc in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /home/ssatti/miniconda2/envs/talpy2/lib/python2.7/site-packages/keras/engine/training.pyc in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /home/ssatti/miniconda2/envs/talpy2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /home/ssatti/miniconda2/envs/talpy2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /home/ssatti/miniconda2/envs/talpy2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in __call__(self, *args, **kwargs)
#    1397           ret = tf_session.TF_SessionRunCallable(
#    1398               self._session._session, self._handle, args, status,
# -> 1399               run_metadata_ptr)
#    1400         if run_metadata:
#    1401           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model = load_model(str(os.path.join(DATA_FILES_FULL_PATH, "keras_spell_e217.h5")))
ctable = CharacterTable(read_top_chars())
# Out:
# Reading Val data...
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Read:(100, 60, 100),(100, 60, 100)
#
# Q Virtually all that growth will come from emerging
# A Virtually all that growth will come from emerging
# ☒ Virtually all that growth will come from emerging...........
# ---
# Q knee and was booked.
# A knee and was booked.
# ☒ knee and was booked....................f.... lllt  ffae.....
# ---
# Q
# A
# ☒ aa..................sisss.... rectrellsss...................
# ---
# Q
# A
# ☒ aa..................sisss.... rectrellsss...................
# ---
# Q importantyl, paying customers for bionic suits inspired by
# A importantly, paying customers for bionic suits inspired by
# ☒ importantly, paying customers for boonic suits inspired byy.
# ---
# Q Whether the others left fo their own accord or were
# A Whether the others left of their own accord or were
# ☒ Whether the others left ff their own accord or wereee,."....
# ---
# Q DirecTV earnings beat estimates, sending its shares up 6.2
# A DirecTV earnings beat estimates, sending its shares up 6.2
# ☒ Directe earnings beat estimates, sending its shares up 6666.
# ---
# Q Queen Jodie Ampproximately
# A Queen Jodie Approximately
# ☒ Queen Jodie Approximately..y................................
# ---
# Q The problem we had is veeryone is vying for the same
# A The problem we had is everyone is vying for the same
# ☒ The problem we had is veryyone is leing for the same..,,"...
# ---
# Q intended to pour 55-gallon drums of unspeciifed
# A intended to pour 55-gallon drums of unspecified
# ☒ intended to pour 55-gallon drums of unspecifiedd............
# ---

# %%
def generate_question2(answer):
    """Returns answer, answer"""
    #question = add_noise_to_string(answer, AMOUNT_OF_NOISE)
    # Add padding:
    #question += PADDING * (CONFIG.max_input_len - len(question))
    answer += PADDING * (CONFIG.max_input_len - len(answer))
    return answer, answer

def generator3(file_name):
    """
    Input is a file name. Expected to loop over indefinitely. Not sure. Don't rely on it. DO manually
    """
    ctable = CharacterTable(read_top_chars())
    batch_of_answers = []
    while True:
        with open(file_name) as answers:
            for answer in answers:
                batch_of_answers.append(answer.strip().decode('utf-8'))
                if len(batch_of_answers) == CONFIG.batch_size:
                    #random_shuffle(batch_of_answers)
                    batch_of_questions = []
                    for answer_index, answer in enumerate(batch_of_answers):
                        question, answer = generate_question2(answer)
                        batch_of_answers[answer_index] = answer
                        assert len(answer) == CONFIG.max_input_len
                        question = question[::-1] if CONFIG.inverted else question
                        batch_of_questions.append(question)
                    X, y = _vectorize(batch_of_questions, batch_of_answers, ctable)
                    yield X, y
                    batch_of_answers = []

def generator4(list_of_queries):
    """
    Input is list of queries. DO manually. Careful about length > 60
    """
    ctable = CharacterTable(read_top_chars())
    batch_of_answers = []
    for answer in list_of_queries:
        if len(answer)>CONFIG.max_input_len: #Tweaked here
            answer = answer[:CONFIG.max_input_len]
        batch_of_answers.append(answer.strip().decode('utf-8'))
        if len(batch_of_answers) == CONFIG.batch_size:
            #random_shuffle(batch_of_answers)
            batch_of_questions = []
            for answer_index, answer in enumerate(batch_of_answers):
                question, answer = generate_question2(answer)
                batch_of_answers[answer_index] = answer
                if len(answer) != CONFIG.max_input_len:
                    print(answer,len(answer),CONFIG.max_input_len)
                assert len(answer) == CONFIG.max_input_len
                question = question[::-1] if CONFIG.inverted else question
                batch_of_questions.append(question)
            X, y = _vectorize(batch_of_questions, batch_of_answers, ctable)
            yield X, y
            batch_of_answers = []

def print_random_predictions2(model, ctable, X_val, y_val):
    #Prints on screen
    print()
    for ind in range(99,-1,-1):
        #ind = random_randint(0, len(X_val))
        rowX, rowy = X_val[np.array([ind])], y_val[np.array([ind])] # pylint:disable=no-member
        preds = model.predict_classes(rowX, verbose=0)
        q = ctable.decode(rowX[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        if CONFIG.inverted:
            print('Q', q[::-1]) # inverted back!
        else:
            print('Q', q)
        print('A', correct)
        print(Colors.green + '☑' + Colors.close if correct == guess else Colors.red + '☒' + Colors.close, guess)
        print('---')
    print()

def print_random_predictions3(model, ctable, X_val, y_val,fN_out='./end_tal_pred.txt'):
    #Prints in a file
    fp = open(fN_out,'a+')
    for ind in range(99,-1,-1):
        #ind = random_randint(0, len(X_val))
        rowX, rowy = X_val[np.array([ind])], y_val[np.array([ind])] # pylint:disable=no-member
        preds = model.predict_classes(rowX, verbose=0)
        q = ctable.decode(rowX[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        #if CONFIG.inverted:
        #    print('Q', q[::-1]) # inverted back!
        #else:
        #    print('Q', q)
        #print('A', correct)
        #print(Colors.green + '☑' + Colors.close if correct == guess else Colors.red + '☒' + Colors.close, guess)
        idx = int(guess.find(".."))
        if idx!=-1:
            fp.write(guess[:idx].encode('utf8'))
        else:
            fp.write(guess)
        fp.write('\n')
        #print('---')
    fp.close()

# %%
print("Reading Val data...")
NEWS_FILE_NAME_VALIDATE = os.path.join(DATA_FILES_FULL_PATH, "try_val3.txt")
file_gen = generator3(NEWS_FILE_NAME_VALIDATE)
X_val, y_val = next(file_gen)
#print(X_val[0])
#print(y_val[0])
#print("Next one")
#print(X_val[1])
#print(y_val[1])
print("Read:"+str(X_val.shape)+","+str(y_val.shape))
print_random_predictions2(model, ctable, X_val, y_val)
#print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
#X_val, y_val = next(generator3(NEWS_FILE_NAME_VALIDATE))
#print("Read:"+str(X_val.shape)+","+str(y_val.shape))
#print_random_predictions2(model, ctable, X_val, y_val)
# Out:
# Reading Val data...
# Read:(100, 60, 100),(100, 60, 100)
#
# Q 106.9 free fm
# A 106.9 free fm
# ☒ 16.99 free foom.....................eeuutee.llls  aae.......
# ---
# Q spring break in mexico
# A spring break in mexico
# ☒ spring break in mexicom.................t.... llt...........
# ---
# Q coyote fox
# A coyote fox
# ☒ coyote fox....................... ressureeellss..a..........
# ---
# Q herbergers
# A herbergers
# ☒ herbergress.............ass.......resstureellss.............
# ---
# Q where is the sentinel node
# A where is the sentinel node
# ☒ where is the sentincl  ooee.................................
# ---
# Q efavirenz
# A efavirenz
# ☒ efaaireenn.......................feesttreellss..g...........
# ---
# Q capt bryan willard
# A capt bryan willard
# ☒ capt broan willard....................utt....llts...........
# ---
# Q sanctions
# A sanctions
# ☒ sanctions.................s.......eestrreellss..............
# ---
# Q conan obrien show
# A conan obrien show
# ☒ connn  briee show......................tt....llls...........
# ---
# Q cng
# A cng
# ☒ cing...................iss.....eeestorellsss.;;.......eeeee.
# ---
# Q i discovered the four moons of saturn
# A i discovered the four moons of saturn
# ☒ i discovered the  ourr monss of sturrn...........iit.......n
# ---
# Q business malaysia
# A business malaysia
# ☒ business malaysia...................eeutte..lllss...........
# ---
# Q dwayne lowe
# A dwayne lowe
# ☒ dwaye  lowee......................resutreeellsssaaa.........
# ---
# Q unemployment rate in the great depression
# A unemployment rate in the great depression
# ☒ unemployment rate in the great depression........tt.......et
# ---
# Q sam sloat
# A sam sloat
# ☒ sam sllatt.......................fresstrreellsss aa.........
# ---
# Q village of mineola ny
# A village of mineola ny
# ☒ village of minell anyy........................lls...........
# ---
# Q colostomy management
# A colostomy management
# ☒ colostomy management...............reeuut.....lls...........
# ---
# Q neyo time instrumental
# A neyo time instrumental
# ☒ neyo time instrumentall.......................olss..........
# ---
# Q working couples
# A working couples
# ☒ working couples....................reeuute..lllss.a.........
# ---
# Q san isidro costa rica
# A san isidro costa rica
# ☒ san is dee costa  iccaa.................tt....llss..........
# ---
# Q galesville maryland
# A galesville maryland
# ☒ galesiible maryland.................eeuut....llls..a........
# ---
# Q kpdk
# A kpdk
# ☒ kllk...................ss..... eesttreellss.................
# ---
# Q sacramento ca
# A sacramento ca
# ☒ sacrament.oca.............iie.....feeestueelllsss...........
# ---
# Q vasomotor symptoms
# A vasomotor symptoms
# ☒ vasomotor symptoms.................reeutt....llls...........
# ---
# Q rubber metal seal
# A rubber metal seal
# ☒ rubber metal seal..................rreutt....llss...........
# ---
# Q indian bend park
# A indian bend park
# ☒ indian bend park.....................uutt....llss...........
# ---
# Q bumps in mouth
# A bumps in mouth
# ☒ bumps in mouth.....................reeuute..lllss.aa........
# ---
# Q north carolina hazmat
# A north carolina hazmat
# ☒ north carolina hammat........................llls...........
# ---
# Q 9th circut court
# A 9th circut court
# ☒ 9tt circut court..................rreestr....llls...........
# ---
# Q the big read
# A the big read
# ☒ the big read..............t........reeuute..lllss aaa.......
# ---
# Q usgs real time water data
# A usgs real time water data
# ☒ uses real time water data.....................ll............
# ---
# Q cummins
# A cummins
# ☒ cummins...........ee....ssse.....scotfeellss...."".........e
# ---
# Q centro medico paitilla
# A centro medico paitilla
# ☒ centro medico patiillll......................lllts..........
# ---
# Q government auditing standards
# A government auditing standards
# ☒ government auditing standards...............................
# ---
# Q poker
# A poker
# ☒ poker...................is......seotorellls.............e.ee
# ---
# Q commercial propane grill
# A commercial propane grill
# ☒ commercial propage grill......................lls...........
# ---
# Q tax returns online
# A tax returns online
# ☒ tax returns online.................eeesure...llls...........
# ---
# Q footballhalloffame
# A footballhalloffame
# ☒ football haloofaame...................sttt...lllss.aa.......
# ---
# Q bend oregon newspaper
# A bend oregon newspaper
# ☒ bend oregon newspaper.........................llss.aa.......
# ---
# Q salary employees
# A salary employees
# ☒ salary employees...................peeuute..lllss...........
# ---
# Q outlook express
# A outlook express
# ☒ outlook express....................reeuut...lllss...........
# ---
# Q doug scofield
# A doug scofield
# ☒ doug scoffedd.......................sstttee.lllss aaee......
# ---
# Q simple search
# A simple search
# ☒ simple search............tt.......rreuurre.llsss............
# ---
# Q horror scopes
# A horror scopes
# ☒ horror scopes............tt.......freecuteelllss............
# ---
# Q child disability
# A child disability
# ☒ child disability..........t.........reuut... lloss fa.......
# ---
# Q fafsa financial aid
# A fafsa financial aid
# ☒ fafsa financial aid..........................llls...........
# ---
# Q white girls
# A white girls
# ☒ white girls.......................rreeutre.lllss aagd.......
# ---
# Q taxable pensions
# A taxable pensions
# ☒ taxable pensions...................eeesure...llss...........
# ---
# Q 6 or 7 passenger suv
# A 6 or 7 passenger suv
# ☒ 6 or 7 passenger suze................ uute...llls...........
# ---
# Q powerball results
# A powerball results
# ☒ powerball results.....................ut....lllss...........
# ---
# Q trailer manifest box
# A trailer manifest box
# ☒ trailer manifest box..................uute...llls...........
# ---
# Q dragons metal ages
# A dragons metal ages
# ☒ dragoos metal ages..................eeuute...llls..a........
# ---
# Q kern county personnel department
# A kern county personnel department
# ☒ zern county personnel department............................
# ---
# Q timesunions
# A timesunions
# ☒ timesuuions...............t.......frestureellsss.aa.........
# ---
# Q grace under fire
# A grace under fire
# ☒ grace under fire..................rreeuut....llls...........
# ---
# Q car rental debit card
# A car rental debit card
# ☒ car rental debit card..................tt....lllss age......
# ---
# Q pasture roller
# A pasture roller
# ☒ pasture roller....................frrestrre.llsss...........
# ---
# Q golfsmith
# A golfsmith
# ☒ golfsmithh.......................eresorreelllss.a...........
# ---
# Q adelaide
# A adelaide
# ☒ adelaide.................i.......rsotfeelllss...............
# ---
# Q qvc
# A qvc
# ☒ vic..................isss.... eectrrellsss...............ee.
# ---
# Q ashley furniture
# A ashley furniture
# ☒ askley furniture...................reeuutr...llls...........
# ---
# Q real ghost pictures
# A real ghost pictures
# ☒ real ghoss pictures...................utt....lllss..........
# ---
# Q cosmotology insurance
# A cosmotology insurance
# ☒ compottolgy insurance..................ft.....llss..........
# ---
# Q brushed cotton appliqued bathrobes
# A brushed cotton appliqued bathrobes
# ☒ brushed cotton appliqued bathrooes..........................
# ---
# Q radon
# A radon
# ☒ radon...................sise.....sootreells..";""".........e
# ---
# Q z95 the bone
# A z95 the bone
# ☒ 19 the bone...............ss.......ssuuteeellsss age........
# ---
# Q savingsbond value
# A savingsbond value
# ☒ savingsbonnd value..................restt....lllss.aa.......
# ---
# Q morongo reservation
# A morongo reservation
# ☒ moronon reservation...................utt....llls...........
# ---
# Q interacial gallery
# A interacial gallery
# ☒ interaciid gallery...................suttr...lllss.aa.......
# ---
# Q xanax
# A xanax
# ☒ manax...................iss.....restorellls..;;""..........e
# ---
# Q marion cotillard
# A marion cotillard
# ☒ marion cotilalrd...................reeuute...llss...........
# ---
# Q cynthia
# A cynthia
# ☒ cynthil..................ise.....ssotteellss...............e
# ---
# Q conversion disorder
# A conversion disorder
# ☒ conversion disorder.................reutte...lllss..........
# ---
# Q jacqueline kennedy
# A jacqueline kennedy
# ☒ lacqueline kennedy..................reuutr...llss...........
# ---
# Q detroit board of education
# A detroit board of education
# ☒ detroit board of education....................ll............
# ---
# Q calvin coolidge
# A calvin coolidge
# ☒ calving collider..........t........rreettoe..lllss agee.....
# ---
# Q why is movement inportant
# A why is movement inportant
# ☒ why is movement inportant.....................yy............
# ---
# Q kuzz fm
# A kuzz fm
# ☒ juzz ffmm........................eescoreellys...............
# ---
# Q syracuse china
# A syracuse china
# ☒ syracuse china............ts.......eeestureellss............
# ---
# Q futons
# A futons
# ☒ futonss..................is......sootfeellss..;;:""........e
# ---
# Q cfc charities
# A cfc charities
# ☒ oocccharities.....................rreeuuteelllsss...........
# ---
# Q living will
# A living will
# ☒ living will.......................rrestureelllsssaaa........
# ---
# Q columbia southern
# A columbia southern
# ☒ columbia southern.........''......fereuute...llss...........
# ---
# Q average cost of a new roof
# A average cost of a new roof
# ☒ average cost of a new roof....................ls............
# ---
# Q manateecounty
# A manateecounty
# ☒ manate county.............t........eesstufeellsss aa........
# ---
# Q washington state dot
# A washington state dot
# ☒ washington state dott...............r.uut.....llss..........
# ---
# Q marshfield mass
# A marshfield mass
# ☒ marssfilld mass....................reeutre..llss............
# ---
# Q la puerta de san juan
# A la puerta de san juan
# ☒ la purraa de san juann..................t....ylls...........
# ---
# Q south dakota census
# A south dakota census
# ☒ south dakota census..................fuute....llss..........
# ---
# Q homepath fannie mae
# A homepath fannie mae
# ☒ homepath fannie maee.................uuutte..lllss..........
# ---
# Q michelinb2b
# A michelinb2b
# ☒ micheling b........................eeettrey.llsws i aad.....
# ---
# Q baby porn
# A baby porn
# ☒ baby porn........................reesurrellls...."""........
# ---
# Q blackhorse
# A blackhorse
# ☒ blackhorses..............ss.......resutreellss..............
# ---
# Q iih symptoms
# A iih symptoms
# ☒ iis  ymptoms.......................eeectteelllsss aa........
# ---
# Q michigan department of revenue
# A michigan department of revenue
# ☒ michigan department of revenue..............................
# ---
# Q ksp chemistry
# A ksp chemistry
# ☒ sspp hemistryy.....................eeesttfe.llssssaa........
# ---
# Q n
# A n
# ☒ nn ..................siss..... eetoreellss..................
# ---
# Q win a vegas vacation
# A win a vegas vacation
# ☒ win a megas vacation.........................llls...........
# ---
# Q aspiration pneumonia
# A aspiration pneumonia
# ☒ aspiration penemoniaa.................fttte..lllss..........
# ---
# Q he had a sex change
# A he had a sex change
# ☒ he had a sex change...................utt....llls...........
# ---

# %%
X_val, y_val = next(file_gen)
print("Read:"+str(X_val.shape)+","+str(y_val.shape))
print_random_predictions2(model, ctable, X_val, y_val)
# Out:
# Read:(100, 60, 100),(100, 60, 100)
#
# Q goddess severa
# A goddess severa
# ☒ goddess several...........t....... restuty..lllss.a.........
# ---
# Q manila philippine map
# A manila philippine map
# ☒ maniaa philippine map.........................llss..........
# ---
# Q gsa global
# A gsa global
# ☒ ssa global........................reeutteeellsss aad........
# ---
# Q lyndon b johnson pics
# A lyndon b johnson pics
# ☒ lyndon by jonsoonppics........................llls..a.......
# ---
# Q hostile working environment
# A hostile working environment
# ☒ hostile working environment.................................
# ---
# Q american dreams 2002
# A american dreams 2002
# ☒ american dreams 2002...................tt.... lls...........
# ---
# Q edison glass lyrics
# A edison glass lyrics
# ☒ edison glass lyrrcs...................uutr...lllss..........
# ---
# Q mensfaq
# A mensfaq
# ☒ mensfai..................ss......ssttreellss................
# ---
# Q semantic insight
# A semantic insight
# ☒ semantic insight....................reuut....llls  age......
# ---
# Q olympic national park washington
# A olympic national park washington
# ☒ olyppic national park washington...................ee.......
# ---
# Q throat crusher
# A throat crusher
# ☒ throat crusher....................freeuurr..lllss...........
# ---
# Q shark valley visitor center
# A shark valley visitor center
# ☒ shark valled visitor center.................................
# ---
# Q equestrian products
# A equestrian products
# ☒ equestrian products................reeuttr...lllss..........
# ---
# Q eighth amendment
# A eighth amendment
# ☒ eighth amendment.....................eutr...lllss.aa........
# ---
# Q name
# A name
# ☒ name...................iss.... eeecorrellss..;"":..........e
# ---
# Q norwalk theater
# A norwalk theater
# ☒ norwalk theater...........t.......ereeuute..lllss...........
# ---
# Q pc software
# A pc software
# ☒ cp software..............tt........restureeellsss aad.......
# ---
# Q macted
# A macted
# ☒ matted..................iie......stoffeellss.aag::..........
# ---
# Q nj tenant laws
# A nj tenant laws
# ☒ on tenant laws....................reeettte..llss............
# ---
# Q short ragweed
# A short ragweed
# ☒ short raggeed......................reeutte..lllss aae.......
# ---
# Q utah real estate
# A utah real estate
# ☒ auth real estatee..................reeuutee..llss...........
# ---
# Q dave wireless
# A dave wireless
# ☒ dave wireless.............t........reeuute.lllss............
# ---
# Q female pedophilia
# A female pedophilia
# ☒ female pedophilia....................eut....lllss...........
# ---
# Q utswmc
# A utswmc
# ☒ utssma...................ss.......sotteelllsss..............
# ---
# Q dxg blue camcorder
# A dxg blue camcorder
# ☒ dig blue camporder....................ut....lllss...........
# ---
# Q corel dvd movie factory
# A corel dvd movie factory
# ☒ corlee did movve factory......................llls..a.......
# ---
# Q doughrussell
# A doughrussell
# ☒ doughrussell..............s.......reestuteelllss............
# ---
# Q usa jobs
# A usa jobs
# ☒ usa jjobs................ss......peesttreellsss aa..........
# ---
# Q denver county jail
# A denver county jail
# ☒ denver county jail....................utrr..llltssaaee......
# ---
# Q earda
# A earda
# ☒ earda....................is......ssttreellss..;............e
# ---
# Q internet movies
# A internet movies
# ☒ internet movies....................reecute..lllss...........
# ---
# Q small business finance
# A small business finance
# ☒ small business finance.......................llls...........
# ---
# Q tn career center
# A tn career center
# ☒ tn career center..................freeuutee..llss...........
# ---
# Q western wear
# A western wear
# ☒ western wear.............tts...... resturee.llsss.a.........
# ---
# Q greenguy
# A greenguy
# ☒ greegguyy........................rsotreelllss.ang:..........
# ---
# Q heritage rally sc
# A heritage rally sc
# ☒ heritage rally scc...................putt....llss...........
# ---
# Q birth defects of the head
# A birth defects of the head
# ☒ birth defects of the head.....................ll............
# ---
# Q dictonaries
# A dictonaries
# ☒ dictonaries.......................restureeellss.............
# ---
# Q tilapia health
# A tilapia health
# ☒ tilipii health............ts.......reetute..llsss.a.........
# ---
# Q removing coffee stains
# A removing coffee stains
# ☒ removing coffee stains........................lls...........
# ---
# Q casi
# A casi
# ☒ casis..................iss.....seectrrellss..;;:...........e
# ---
# Q shoulder exercise
# A shoulder exercise
# ☒ shoulder exercise...................eeuut....llss...........
# ---
# Q mortgage interest refund
# A mortgage interest refund
# ☒ mortgage interest refund......................lls...........
# ---
# Q buffering r o water before adding salt
# A buffering r o water before adding salt
# ☒ buffering oo wwaee before addinggsallt..........fiie........
# ---
# Q zaxbys
# A zaxbys
# ☒ gabbys..................ssse.....ssotrellls..?"""".........e
# ---
# Q celebrity s nude
# A celebrity s nude
# ☒ celebrity ss unde...................resttee..lllss.aa.......
# ---
# Q 1st earth day
# A 1st earth day
# ☒ 1st earth day.............t........rrestte..yllss aage......
# ---
# Q food calories
# A food calories
# ☒ food calories......................reeuute..lllss.aae.......
# ---
# Q gravity
# A gravity
# ☒ gravity..........................ssotoreellss.aa?::.........
# ---
# Q customs decals
# A customs decals
# ☒ customs decalss................... restut...lllss...........
# ---
# Q demetria turner
# A demetria turner
# ☒ demetria turner...........t.......freesture..llss...........
# ---
# Q robert frost inauguration
# A robert frost inauguration
# ☒ robert frost inauguration...................tlll............
# ---
# Q young gymnasts gallery
# A young gymnasts gallery
# ☒ young gyannsts galleryy.......................lls...........
# ---
# Q kristi lynn
# A kristi lynn
# ☒ gristi llnnn.............tss......fresttreelllsssaa.........
# ---
# Q build brick porch
# A build brick porch
# ☒ build brick porch.....................utte...lllss aree.....
# ---
# Q firing range
# A firing range
# ☒ firing range..............t........reeture.dllss..a.........
# ---
# Q godvd
# A godvd
# ☒ godd.d.................iss.... eesctreellyss..""".........ee
# ---
# Q wilkinson disease
# A wilkinson disease
# ☒ willinsonndiseasee..................eeuut....llsss.a........
# ---
# Q curb crete
# A curb crete
# ☒ curb crette......................weesetteeellss.............
# ---
# Q symptoms of appendicitis
# A symptoms of appendicitis
# ☒ symptoms of appendicisiss.....................lls...........
# ---
# Q florida lawyers
# A florida lawyers
# ☒ florida lawyers...........t'.......reeuute..llsss aa........
# ---
# Q tax requirements
# A tax requirements
# ☒ tax requirements..........i.......fee uute..llls............
# ---
# Q free download videos from youtube
# A free download videos from youtube
# ☒ free download videos from youtube..................e........
# ---
# Q frank lucas
# A frank lucas
# ☒ frank lucas...............is......peestureelllss.aa.........
# ---
# Q cir registry
# A cir registry
# ☒ cir registry.............ttse......eeestureellsss aagd......
# ---
# Q shunt operation
# A shunt operation
# ☒ shunt operation....................eeeuurr..lllss...........
# ---
# Q kitchen cubboards
# A kitchen cubboards
# ☒ kitchen cubboards...................eeutt....llss  aaee.....
# ---
# Q procrastenation
# A procrastenation
# ☒ procrastentatoon..........ti......fee sture.llss............
# ---
# Q cnet free download
# A cnet free download
# ☒ cent free download....................ftr... llts.aa........
# ---
# Q rhyming words
# A rhyming words
# ☒ whyming words............ttss.......resttreelllss agee......
# ---
# Q projected gasoline prices
# A projected gasoline prices
# ☒ projected gassoine prices.....................llt...........
# ---
# Q scams on the net
# A scams on the net
# ☒ scams on the net...................reeutt....llss...........
# ---
# Q ncaa tournament
# A ncaa tournament
# ☒ nnca  tounnament....................resttre..llsss.a........
# ---
# Q remington coal company in wv
# A remington coal company in wv
# ☒ reminnion coal company in week..............................
# ---
# Q waterville valley
# A waterville valley
# ☒ waterville valley....................uuut....llss. a........
# ---
# Q map of spain
# A map of spain
# ☒ map of spain.............tis.......reestreelllss............
# ---
# Q define workplace violence
# A define workplace violence
# ☒ define workplace violence.....................ls............
# ---
# Q snags
# A snags
# ☒ snagss..................sise.....ssotreellsssia?::".........
# ---
# Q national fire protection association
# A national fire protection association
# ☒ national fire protection association............siee........
# ---
# Q shadow zone
# A shadow zone
# ☒ shadow zone........................rsutteelllsss ia.........
# ---
# Q define sleep apnea
# A define sleep apnea
# ☒ define sleep aaena...................sutt....llls...........
# ---
# Q lone star park
# A lone star park
# ☒ lone star park......................eeuute..lllss.aa........
# ---
# Q rate my
# A rate my
# ☒ rate my.................ss.......ssotreellss................
# ---
# Q maytag mdb5601
# A maytag mdb5601
# ☒ maytag md  0011.....................eeuutee.lllss  aad......
# ---
# Q tqm in education
# A tqm in education
# ☒ tim in education...................reetut...lllss...........
# ---
# Q cervical mri
# A cervical mri
# ☒ cervical mrii.....................rreeuute..llfs..a.........
# ---
# Q wheat harvest
# A wheat harvest
# ☒ wheat harvest............tt........reeutte..lllss.aa........
# ---
# Q thompson starrett
# A thompson starrett
# ☒ thompson startett..................reeuut....llss...........
# ---
# Q questlaboratories
# A questlaboratories
# ☒ questaaboatorries....................euurr...llsssa.........
# ---
# Q mug shot database
# A mug shot database
# ☒ mug shot databaase...................sftt...lllss.aa........
# ---
# Q consumer report on generators
# A consumer report on generators
# ☒ consumer report on generators...............................
# ---
# Q jacksonville limousine
# A jacksonville limousine
# ☒ lacksonville limoosinee.......................lls...........
# ---
# Q juicer jack la lanne
# A juicer jack la lanne
# ☒ juicer lack la lanne..................uttr...lllss..........
# ---
# Q google
# A google
# ☒ google...................iie.... sootfeellss...........eeeee
# ---
# Q lcm
# A lcm
# ☒ lccm...................iss.....seestrrell.s..;;......teeeee.
# ---
# Q sunnyvale isd
# A sunnyvale isd
# ☒ sunnyaale isdd......................sstttee.llsss aaee......
# ---
# Q the black migration
# A the black migration
# ☒ the black migration...................utt....lllss..........
# ---
# Q associated press
# A associated press
# ☒ associated press..........t.......feessure..lllss...........
# ---
# Q sample letter of intent for employment
# A sample letter of intent for employment
# ☒ sample letter of intent for employment..........iiee........
# ---
# Q instrument stores in maryland
# A instrument stores in maryland
# ☒ instrument stores in marrland...............................
# ---

# %%
# %load_ext autoreload
# %autoreload 2

def read_end2end(flag=0):
    file='./end_to_end_queries.tsv'
    data=[]
    valid=[]
    lens=[]

    single_file='./end_queries.txt'
    s_file=open(single_file,'w')

    with open(file) as f:
        for line in f:
            part=line.strip().split('\t')
            data.append(part[0])
            valid.append(part[1:])
            lens.append(len(valid[-1]))
            # if lens[-1]>1:
            #     print(valid[-1])

            if flag==1:
                s_file.write(part[0])
                s_file.write('\n')

    print(file, len(data),Counter(lens))
    return data,valid

from eval_all import *
# dir(eval_all)
jdb_X,jdb_Y,jdb_tX,jdb_tY=read_jdb()
#trec_X,trec_Y=read_trec()
#qspell_X,qspell_Y=read_qspell()
#jdb_X.extend(jdb_tX)
#print(len(jdb_X),len(jdb_tX))
X,Y=read_end2end()
print(len(X))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ('./JDBv1.0/train.txt', 6000, Counter({1: 5548, 2: 434, 3: 15, 4: 3}))
# ('./JDBv1.0/test-split1.txt', 1711, Counter({1: 1581, 2: 126, 3: 4}))
# ('./JDBv1.0/test-split2.txt', 1711, Counter({1: 1567, 2: 137, 3: 7}))
# ('./JDBv1.0/test-split3.txt', 1711, Counter({1: 1574, 2: 131, 3: 5, 4: 1}))
# ('Train:', 6000)
# ('Test:', 5133)
# ./end_to_end_queries.tsv 249 Counter({1: 249})
# 249

# %%
#Make sure it is in multiples of 100. Else add stuff towards end of the list
lst = []
need_stuff=int(100-len(X)%100)
print("Needed stuff:"+str(need_stuff))
for i in range(need_stuff):
    lst.append(X[-1])
X.extend(lst)
print(len(X))
print("Reading end_end data")
file_gen4 = generator4(X)
num_lines = 0
while True:
    try:
        X_val, y_val = next(file_gen4)
        num_lines+=int(len(X_val))
        print_random_predictions3(model, ctable, X_val, y_val)
        print(str(num_lines)+" done")
    except StopIteration:
        print("Done at:"+str(num_lines))
        break
print("Make sure you remove the last "+str(need_stuff)+" lines")
# Out:
# Needed stuff:51
# 300
# Reading end_end data
# 100 done
# 200 done
# 300 done
# Done at:300
# Make sure you remove the last 51 lines

# %%
num=0
for i in jdb_X:
    if len(i)>60:
        print(i,len(i))
        num+=1
print(num)
# Out:
# tremors 4 the legend begins coustum of a tremor for holloween for kids 70
# what are some important factors to consider when designing a sustainable green home for a client 96
# usefulness of accounting information to investors and creditors 63
# emerging leaders program department of health and human services 64
# free photos of fat sexy horny nude white women having anal sex 62
# this is the way the the world ends not with a bang with a wimper 64
# 6
